# %%
## This notebook is used to average the monthly ERA5 geopotential data to get yearly data
## Created by Kendra Herweck

# %%
import netCDF4 as nc
import numpy as np
import datetime as dt  # Python standard library datetime  module
from netCDF4 import Dataset  # http://code.google.com/p/netcdf4-python/
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from astropy.table import Table
from astropy.io import ascii
from pandas import read_csv
from matplotlib.dates import DateFormatter
from pandas import DataFrame
from pandas import Grouper
import matplotlib.dates as mdates
import cartopy.crs as ccrs
import xarray as xr
from glob import glob

# %% [markdown]
# ## Average Monthly to get Yearly

# %%
filename1 = 'Data/Geopotential-Data/ERA/adaptor.mars.internal-1625062304.0616617-22877-6-c384723f-646f-4a10-9167-6d8295da1c75_1950-1978.nc'
ds1 = xr.open_dataset(filename1)
filename2 = 'Data/Geopotential-Data/ERA/adaptor.mars.internal-1625062274.2717822-19005-7-0b203d2e-afd5-4f69-8018-c096fde2d646_1979-2020.nc'
ds2 = xr.open_dataset(filename2)
ds = xr.merge([ds1,ds2])

print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 361, longitude: 1440, time: 284)
# Coordinates:
#   * time       (time) datetime64[ns] 1950-01-01 1950-02-01 ... 2020-12-01
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... 0.75 0.5 0.25 0.0
# Data variables:
#     z          (time, latitude, longitude) float32 4.965e+04 ... 5.744e+04

# %%
ds_yearly = ds.groupby('time.year').mean('time',skipna=True)
print(ds_yearly.values)

# %%
print(ds_yearly['year'])

# %%
for i in range(0,len(ds_yearly['year'])): ##len(ds_yearly['year'])
    year = ds_yearly['year'][i].values
    filename = 'Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-{}.nc'.format(year)
    print(filename)
    f = nc.Dataset(filename, 'w')
    f.createDimension('time', 1)
    f.createDimension('y', len(ds_yearly['latitude'][0:321]))
    f.createDimension('x', len(ds_yearly['longitude']))
    lats = f.createVariable('lat', float, ('y', ), zlib=True)
    #print(lats.shape)
    lons = f.createVariable('lon', float, ('x', ), zlib=True)
    gpot = f.createVariable('gpot', float, ('y', 'x'), zlib=True, least_significant_digit=1, fill_value=0)
    time = f.createVariable('time',float,('time'),zlib=True)
    
    lat_out  = np.array(ds_yearly.variables['latitude'][0:321])
    #print(lat_out.shape)
    lon_out  = ds_yearly.variables['longitude']
    #print(lat_out)
   # wind = ds_test['u'][i,0:321,:].values
    #print(lon_out.shape)
    lats[:] = lat_out
    lons[:] = lon_out
    gpot[:] = ds_yearly['z'][i,0:321,:].values
    time[:] = ds_yearly['year'][i].values
    #wind_data = np.array(ds_test['u'][i,0:321,:].values)
    #print(wind_data.shape)
    #print(wind)
    #data = []
    #for i in range (0, len(lat_out)):
    #    for j in range(0,len(lon_out)):
    #        mean = np.nanmean(combined_ds['U'][0:,0,i,j].values)
    #        data.append(mean)
    #data_out = np.array(data)      ##1d array of data
    #data_out.shape = (len(lat_out),len(lon_out))     ##reshape to 2d array                 
   # f['U'][:,:] = wind_data
   # f['lat'][:] = lat_out
   # f['lon'][:] = lon_out
    f.close()
# Out:
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1950.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1951.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1952.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1953.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1954.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1955.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1956.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1957.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1958.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1959.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1960.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1961.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1962.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1963.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1964.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1965.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1966.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1967.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1968.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1969.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1970.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1971.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1972.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1973.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1974.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1975.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1976.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1977.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1978.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1979.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1980.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1981.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1982.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1983.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1984.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1985.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1986.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1987.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1988.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1989.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1990.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1991.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1992.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1993.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1994.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1995.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1996.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1997.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1998.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-1999.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2000.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2001.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2002.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2003.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2004.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2005.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2006.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2007.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2008.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2009.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2010.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2011.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2012.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2013.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2014.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2015.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2016.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2017.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2018.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2019.nc
# Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2020.nc

# %%
file = 'Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-2020.nc'
ds=xr.open_dataset(file)
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, x: 1440, y: 321)
# Coordinates:
#   * time     (time) float64 2.02e+03
# Dimensions without coordinates: x, y
# Data variables:
#     lat      (y) float64 ...
#     lon      (x) float64 ...
#     gpot     (y, x) float64 ...

# %% [markdown]
# ## Climatological Avg

# %%
filename_list=[]
for i in range(1980,2021):
    filename = 'Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-{}.nc'.format(i)
    filename_list.append(filename)

#print(filename_list)
combined_ds = xr.open_mfdataset(filename_list,concat_dim='time')
#print(combined_ds)

f = nc.Dataset('Climatology_ERA-GeopotentialHeight_500hPa', 'w')
f.createDimension('time', None)
f.createDimension('y', len(combined_ds['lat'][0,:]))
f.createDimension('x', len(combined_ds['lon'][0,:]))
#f.createDimension('level',len(combined_ds['lev']))
lats = f.createVariable('lat', float, ('y', ), zlib=True)
lons = f.createVariable('lon', float, ('x', ), zlib=True)
#levs = f.createVariable('lev',float, ('level', ), zlib= True)
gpot = f.createVariable('gpot', float, ('y', 'x'), zlib=True, least_significant_digit=1, fill_value=0)

# create latitude and longitude 1D arrays
lat_out  = combined_ds.variables['lat'][0,:]
lon_out  = combined_ds.variables['lon'][0,:]

data = []
for i in range (0, len(lat_out)):
    print(lat_out[i].values)
    for j in range(0,len(lon_out)):
        mean = np.nanmean(combined_ds['gpot'][:,i,j].values) #time,lat,lon
        data.append(mean)
data_out = np.array(data)      ##1d array of data
data_out.shape = (len(lat_out),len(lon_out))     ##reshape to 2d array                 
f['gpot'][:] = data_out
f['lat'][:] = lat_out
f['lon'][:] = lon_out
# close file to write on disk
f.close()

# %% [markdown]
# ## Low SIC Avg

# %%
##years: 1950,1951,1952,1955,1958,1959,1961,1964,1966,1968,1970,1971,1974,1976,1977,1979,1981,1984,1987,1989,1990,1993,
##       1995,1997,1998,1999,2002,2005,2007,2010,2011,2012,2015,2016,2019,2020

filename_list=[]
for i in (1950,1951,1952,1955,1958,1959,1961,1964,1966,1968,1970,1971,1974,1976,1977,1979,1981,1984,1987,1989,1990,1993,
      1995,1997,1998,1999,2002,2005,2007,2010,2011,2012,2015,2016,2019,2020):
    filename = 'Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-{}.nc'.format(i)
    filename_list.append(filename)

#print(filename_list)
combined_ds = xr.open_mfdataset(filename_list)
#print(combined_ds)

f = nc.Dataset('LowSIC_ERA-GeopotentialHeight_500hPa', 'w')
f.createDimension('time', None)
f.createDimension('y', len(combined_ds['lat'][0,:]))
f.createDimension('x', len(combined_ds['lon'][0,:]))
#f.createDimension('level',len(combined_ds['lev']))
lats = f.createVariable('lat', float, ('y', ), zlib=True)
lons = f.createVariable('lon', float, ('x', ), zlib=True)
#levs = f.createVariable('lev',float, ('level', ), zlib= True)
gpot = f.createVariable('gpot', float, ('y', 'x'), zlib=True, least_significant_digit=1, fill_value=0)

# create latitude and longitude 1D arrays
lat_out  = combined_ds.variables['lat'][0,:]
lon_out  = combined_ds.variables['lon'][0,:]

data = []
for i in range (0, len(lat_out)):
    print(lat_out[i].values)
    for j in range(0,len(lon_out)):
        mean = np.nanmean(combined_ds['gpot'][:,i,j].values) #time,lat,lon
        data.append(mean)
data_out = np.array(data)      ##1d array of data
data_out.shape = (len(lat_out),len(lon_out))     ##reshape to 2d array                 
f['gpot'][:] = data_out
f['lat'][:] = lat_out
f['lon'][:] = lon_out
# close file to write on disk
f.close()

# %% [markdown]
# ## Low SIC & EP Nino Avg

# %%
##Years: 1952,1970,1977,1987,1998,2007,2012

filename_list=[]
for i in (1952,1970,1977,1987,1998,2007,2012):
    filename = 'Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-{}.nc'.format(i)
    filename_list.append(filename)

#print(filename_list)
combined_ds = xr.open_mfdataset(filename_list)
#print(combined_ds)

f = nc.Dataset('EPNino-LowSIC_ERA-GeopotentialHeight_500hPa', 'w')
f.createDimension('time', None)
f.createDimension('y', len(combined_ds['lat'][0,:]))
f.createDimension('x', len(combined_ds['lon'][0,:]))
#f.createDimension('level',len(combined_ds['lev']))
lats = f.createVariable('lat', float, ('y', ), zlib=True)
lons = f.createVariable('lon', float, ('x', ), zlib=True)
#levs = f.createVariable('lev',float, ('level', ), zlib= True)
gpot = f.createVariable('gpot', float, ('y', 'x'), zlib=True, least_significant_digit=1, fill_value=0)

# create latitude and longitude 1D arrays
lat_out  = combined_ds.variables['lat'][0,:]
lon_out  = combined_ds.variables['lon'][0,:]

data = []
for i in range (0, len(lat_out)):
    print(lat_out[i].values)
    for j in range(0,len(lon_out)):
        mean = np.nanmean(combined_ds['gpot'][:,i,j].values) #time,lat,lon
        data.append(mean)
data_out = np.array(data)      ##1d array of data
data_out.shape = (len(lat_out),len(lon_out))     ##reshape to 2d array                 
f['gpot'][:] = data_out
f['lat'][:] = lat_out
f['lon'][:] = lon_out
# close file to write on disk
f.close()
# Out:
# 90.0
# 89.75
# 89.5
# 89.25
# 89.0
# 88.75
# 88.5
# 88.25
# 88.0
# 87.75
# 87.5
# 87.25
# 87.0
# 86.75
# 86.5
# 86.25
# 86.0
# 85.75
# 85.5
# 85.25
# 85.0
# 84.75
# 84.5
# 84.25
# 84.0
# 83.75
# 83.5
# 83.25
# 83.0
# 82.75
# 82.5
# 82.25
# 82.0
# 81.75
# 81.5
# 81.25
# 81.0
# 80.75
# 80.5
# 80.25
# 80.0
# 79.75
# 79.5
# 79.25
# 79.0
# 78.75
# 78.5
# 78.25
# 78.0
# 77.75
# 77.5
# 77.25
# 77.0
# 76.75
# 76.5
# 76.25
# 76.0
# 75.75
# 75.5
# 75.25
# 75.0
# 74.75
# 74.5
# 74.25
# 74.0
# 73.75
# 73.5
# 73.25
# 73.0
# 72.75
# 72.5
# 72.25
# 72.0
# 71.75
# 71.5
# 71.25
# 71.0
# 70.75
# 70.5
# 70.25
# 70.0
# 69.75
# 69.5
# 69.25
# 69.0
# 68.75
# 68.5
# 68.25
# 68.0
# 67.75
# 67.5
# 67.25
# 67.0
# 66.75
# 66.5
# 66.25
# 66.0
# 65.75
# 65.5
# 65.25
# 65.0
# 64.75
# 64.5
# 64.25
# 64.0
# 63.75
# 63.5
# 63.25
# 63.0
# 62.75
# 62.5
# 62.25
# 62.0
# 61.75
# 61.5
# 61.25
# 61.0
# 60.75
# 60.5
# 60.25
# 60.0
# 59.75
# 59.5
# 59.25
# 59.0
# 58.75
# 58.5
# 58.25
# 58.0
# 57.75
# 57.5
# 57.25
# 57.0
# 56.75
# 56.5
# 56.25
# 56.0
# 55.75
# 55.5
# 55.25
# 55.0
# 54.75
# 54.5
# 54.25
# 54.0
# 53.75
# 53.5
# 53.25
# 53.0
# 52.75
# 52.5
# 52.25
# 52.0
# 51.75
# 51.5
# 51.25
# 51.0
# 50.75
# 50.5
# 50.25
# 50.0
# 49.75
# 49.5
# 49.25
# 49.0
# 48.75
# 48.5
# 48.25
# 48.0
# 47.75
# 47.5
# 47.25
# 47.0
# 46.75
# 46.5
# 46.25
# 46.0
# 45.75
# 45.5
# 45.25
# 45.0
# 44.75
# 44.5
# 44.25
# 44.0
# 43.75
# 43.5
# 43.25
# 43.0
# 42.75
# 42.5
# 42.25
# 42.0
# 41.75
# 41.5
# 41.25
# 41.0
# 40.75
# 40.5
# 40.25
# 40.0
# 39.75
# 39.5
# 39.25
# 39.0
# 38.75
# 38.5
# 38.25
# 38.0
# 37.75
# 37.5
# 37.25
# 37.0
# 36.75
# 36.5
# 36.25
# 36.0
# 35.75
# 35.5
# 35.25
# 35.0
# 34.75
# 34.5
# 34.25
# 34.0
# 33.75
# 33.5
# 33.25
# 33.0
# 32.75
# 32.5
# 32.25
# 32.0
# 31.75
# 31.5
# 31.25
# 31.0
# 30.75
# 30.5
# 30.25
# 30.0
# 29.75
# 29.5
# 29.25
# 29.0
# 28.75
# 28.5
# 28.25
# 28.0
# 27.75
# 27.5
# 27.25
# 27.0
# 26.75
# 26.5
# 26.25
# 26.0
# 25.75
# 25.5
# 25.25
# 25.0
# 24.75
# 24.5
# 24.25
# 24.0
# 23.75
# 23.5
# 23.25
# 23.0
# 22.75
# 22.5
# 22.25
# 22.0
# 21.75
# 21.5
# 21.25
# 21.0
# 20.75
# 20.5
# 20.25
# 20.0
# 19.75
# 19.5
# 19.25
# 19.0
# 18.75
# 18.5
# 18.25
# 18.0
# 17.75
# 17.5
# 17.25
# 17.0
# 16.75
# 16.5
# 16.25
# 16.0
# 15.75
# 15.5
# 15.25
# 15.0
# 14.75
# 14.5
# 14.25
# 14.0
# 13.75
# 13.5
# 13.25
# 13.0
# 12.75
# 12.5
# 12.25
# 12.0
# 11.75
# 11.5
# 11.25
# 11.0
# 10.75
# 10.5
# 10.25
# 10.0

# %%
f.close()

# %% [markdown]
# ## Low SIC & CP Nino Avg

# %%
#Years: 1958,1959,1964,1966,1995,2005,2010,2015,2016,2020

filename_list=[]
for i in (1958,1959,1964,1966,1995,2005,2010,2015,2016,2020):
    filename = 'Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-{}.nc'.format(i)
    filename_list.append(filename)

#print(filename_list)
combined_ds = xr.open_mfdataset(filename_list)
#print(combined_ds)

f = nc.Dataset('CPNino-LowSIC_ERA-GeopotentialHeight_500hPa', 'w')
f.createDimension('time', None)
f.createDimension('y', len(combined_ds['lat'][0,:]))
f.createDimension('x', len(combined_ds['lon'][0,:]))
#f.createDimension('level',len(combined_ds['lev']))
lats = f.createVariable('lat', float, ('y', ), zlib=True)
lons = f.createVariable('lon', float, ('x', ), zlib=True)
#levs = f.createVariable('lev',float, ('level', ), zlib= True)
gpot = f.createVariable('gpot', float, ('y', 'x'), zlib=True, least_significant_digit=1, fill_value=0)

# create latitude and longitude 1D arrays
lat_out  = combined_ds.variables['lat'][0,:]
lon_out  = combined_ds.variables['lon'][0,:]

data = []
for i in range (0, len(lat_out)):
    print(lat_out[i].values)
    for j in range(0,len(lon_out)):
        mean = np.nanmean(combined_ds['gpot'][:,i,j].values) #time,lat,lon
        data.append(mean)
data_out = np.array(data)      ##1d array of data
data_out.shape = (len(lat_out),len(lon_out))     ##reshape to 2d array                 
f['gpot'][:] = data_out
f['lat'][:] = lat_out
f['lon'][:] = lon_out
# close file to write on disk
f.close()
# Out:
# 90.0
# 89.75
# 89.5
# 89.25
# 89.0
# 88.75
# 88.5
# 88.25
# 88.0
# 87.75
# 87.5
# 87.25
# 87.0
# 86.75
# 86.5
# 86.25
# 86.0
# 85.75
# 85.5
# 85.25
# 85.0
# 84.75
# 84.5
# 84.25
# 84.0
# 83.75
# 83.5
# 83.25
# 83.0
# 82.75
# 82.5
# 82.25
# 82.0
# 81.75
# 81.5
# 81.25
# 81.0
# 80.75
# 80.5
# 80.25
# 80.0
# 79.75
# 79.5
# 79.25
# 79.0
# 78.75
# 78.5
# 78.25
# 78.0
# 77.75
# 77.5
# 77.25
# 77.0
# 76.75
# 76.5
# 76.25
# 76.0
# 75.75
# 75.5
# 75.25
# 75.0
# 74.75
# 74.5
# 74.25
# 74.0
# 73.75
# 73.5
# 73.25
# 73.0
# 72.75
# 72.5
# 72.25
# 72.0
# 71.75
# 71.5
# 71.25
# 71.0
# 70.75
# 70.5
# 70.25
# 70.0
# 69.75
# 69.5
# 69.25
# 69.0
# 68.75
# 68.5
# 68.25
# 68.0
# 67.75
# 67.5
# 67.25
# 67.0
# 66.75
# 66.5
# 66.25
# 66.0
# 65.75
# 65.5
# 65.25
# 65.0
# 64.75
# 64.5
# 64.25
# 64.0
# 63.75
# 63.5
# 63.25
# 63.0
# 62.75
# 62.5
# 62.25
# 62.0
# 61.75
# 61.5
# 61.25
# 61.0
# 60.75
# 60.5
# 60.25
# 60.0
# 59.75
# 59.5
# 59.25
# 59.0
# 58.75
# 58.5
# 58.25
# 58.0
# 57.75
# 57.5
# 57.25
# 57.0
# 56.75
# 56.5
# 56.25
# 56.0
# 55.75
# 55.5
# 55.25
# 55.0
# 54.75
# 54.5
# 54.25
# 54.0
# 53.75
# 53.5
# 53.25
# 53.0
# 52.75
# 52.5
# 52.25
# 52.0
# 51.75
# 51.5
# 51.25
# 51.0
# 50.75
# 50.5
# 50.25
# 50.0
# 49.75
# 49.5
# 49.25
# 49.0
# 48.75
# 48.5
# 48.25
# 48.0
# 47.75
# 47.5
# 47.25
# 47.0
# 46.75
# 46.5
# 46.25
# 46.0
# 45.75
# 45.5
# 45.25
# 45.0
# 44.75
# 44.5
# 44.25
# 44.0
# 43.75
# 43.5
# 43.25
# 43.0
# 42.75
# 42.5
# 42.25
# 42.0
# 41.75
# 41.5
# 41.25
# 41.0
# 40.75
# 40.5
# 40.25
# 40.0
# 39.75
# 39.5
# 39.25
# 39.0
# 38.75
# 38.5
# 38.25
# 38.0
# 37.75
# 37.5
# 37.25
# 37.0
# 36.75
# 36.5
# 36.25
# 36.0
# 35.75
# 35.5
# 35.25
# 35.0
# 34.75
# 34.5
# 34.25
# 34.0
# 33.75
# 33.5
# 33.25
# 33.0
# 32.75
# 32.5
# 32.25
# 32.0
# 31.75
# 31.5
# 31.25
# 31.0
# 30.75
# 30.5
# 30.25
# 30.0
# 29.75
# 29.5
# 29.25
# 29.0
# 28.75
# 28.5
# 28.25
# 28.0
# 27.75
# 27.5
# 27.25
# 27.0
# 26.75
# 26.5
# 26.25
# 26.0
# 25.75
# 25.5
# 25.25
# 25.0
# 24.75
# 24.5
# 24.25
# 24.0
# 23.75
# 23.5
# 23.25
# 23.0
# 22.75
# 22.5
# 22.25
# 22.0
# 21.75
# 21.5
# 21.25
# 21.0
# 20.75
# 20.5
# 20.25
# 20.0
# 19.75
# 19.5
# 19.25
# 19.0
# 18.75
# 18.5
# 18.25
# 18.0
# 17.75
# 17.5
# 17.25
# 17.0
# 16.75
# 16.5
# 16.25
# 16.0
# 15.75
# 15.5
# 15.25
# 15.0
# 14.75
# 14.5
# 14.25
# 14.0
# 13.75
# 13.5
# 13.25
# 13.0
# 12.75
# 12.5
# 12.25
# 12.0
# 11.75
# 11.5
# 11.25
# 11.0
# 10.75
# 10.5
# 10.25
# 10.0

# %% [markdown]
# ## All CP Nino Years

# %%
##Years: 1954,1958,1959,1964,1966,1969,1978,1988,1992,1995,2003,2005,2010,2015,2016,2020

filename_list=[]
for i in (1954,1958,1959,1964,1966,1969,1978,1988,1992,1995,2003,2005,2010,2015,2016,2020):
    filename = 'Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-{}.nc'.format(i)
    filename_list.append(filename)

#print(filename_list)
combined_ds = xr.open_mfdataset(filename_list)
#print(combined_ds)

f = nc.Dataset('CPNino_ERA-GeopotentialHeight_500hPa', 'w')
f.createDimension('time', None)
f.createDimension('y', len(combined_ds['lat'][0,:]))
f.createDimension('x', len(combined_ds['lon'][0,:]))
#f.createDimension('level',len(combined_ds['lev']))
lats = f.createVariable('lat', float, ('y', ), zlib=True)
lons = f.createVariable('lon', float, ('x', ), zlib=True)
#levs = f.createVariable('lev',float, ('level', ), zlib= True)
gpot = f.createVariable('gpot', float, ('y', 'x'), zlib=True, least_significant_digit=1, fill_value=0)

# create latitude and longitude 1D arrays
lat_out  = combined_ds.variables['lat'][0,:]
lon_out  = combined_ds.variables['lon'][0,:]

data = []
for i in range (0, len(lat_out)):
    print(lat_out[i].values)
    for j in range(0,len(lon_out)):
        mean = np.nanmean(combined_ds['gpot'][:,i,j].values) #time,lat,lon
        data.append(mean)
data_out = np.array(data)      ##1d array of data
data_out.shape = (len(lat_out),len(lon_out))     ##reshape to 2d array                 
f['gpot'][:] = data_out
f['lat'][:] = lat_out
f['lon'][:] = lon_out
# close file to write on disk
f.close()
# Out:
# 90.0
# 89.75
# 89.5
# 89.25
# 89.0
# 88.75
# 88.5
# 88.25
# 88.0
# 87.75
# 87.5
# 87.25
# 87.0
# 86.75
# 86.5
# 86.25
# 86.0
# 85.75
# 85.5
# 85.25
# 85.0
# 84.75
# 84.5
# 84.25
# 84.0
# 83.75
# 83.5
# 83.25
# 83.0
# 82.75
# 82.5
# 82.25
# 82.0

# %% [markdown]
# ## All EP Nino Years

# %%
##Years: 1952,1970,1973,1977,1983,1987,1998,2007,2012

filename_list=[]
for i in (1952,1970,1973,1977,1983,1987,1998,2007,2012):
    filename = 'Data/Geopotential-Data/ERA/Yearly/ERA-GeopotentialHeight-{}.nc'.format(i)
    filename_list.append(filename)

#print(filename_list)
combined_ds = xr.open_mfdataset(filename_list)
#print(combined_ds)

f = nc.Dataset('EPNino_ERA-GeopotentialHeight_500hPa', 'w')
f.createDimension('time', None)
f.createDimension('y', len(combined_ds['lat'][0,:]))
f.createDimension('x', len(combined_ds['lon'][0,:]))
#f.createDimension('level',len(combined_ds['lev']))
lats = f.createVariable('lat', float, ('y', ), zlib=True)
lons = f.createVariable('lon', float, ('x', ), zlib=True)
#levs = f.createVariable('lev',float, ('level', ), zlib= True)
gpot = f.createVariable('gpot', float, ('y', 'x'), zlib=True, least_significant_digit=1, fill_value=0)

# create latitude and longitude 1D arrays
lat_out  = combined_ds.variables['lat'][0,:]
lon_out  = combined_ds.variables['lon'][0,:]

data = []
for i in range (0, len(lat_out)):
    print(lat_out[i].values)
    for j in range(0,len(lon_out)):
        mean = np.nanmean(combined_ds['gpot'][:,i,j].values) #time,lat,lon
        data.append(mean)
data_out = np.array(data)      ##1d array of data
data_out.shape = (len(lat_out),len(lon_out))     ##reshape to 2d array                 
f['gpot'][:] = data_out
f['lat'][:] = lat_out
f['lon'][:] = lon_out
# close file to write on disk
f.close()
